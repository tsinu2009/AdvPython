# %%
# import library to allow computer to ping a website and handle json formatted data
import requests 
import json

# %%
url = r"https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh"

# %%
# To check the website is responding well
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
type(resp)
# Out:
# requests.models.Response

# %%
#send a request to the website to return back text data from the API
#returns data as JSON string
str_data = resp.text
str_data
# Out:
# '<!doctype html>\n<html lang="en">\n\n\n  <!--\n  Powered by Socrata\n  http://www.socrata.com\n  -->\n\n  \n\n  <head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="Ncvge3O+ds9JVRoeQJ8/i5r6iuPpgwIlUD9eGCJEX7PiTEwQ/6mUFRAp7B3NkzyP0QupTRmyrWzwa7Oo+NAykQ==" />\n    \n<script src="/javascripts/build/shared/polyfills.js?15f121d5947a8278333c94906e50e1f198ea80a6.2945.1498250080"></script>\n<script>\n//<![CDATA[\nvar socrata = {"approvals":{"settings":{}},"currentUser":null,"domain":"data.nasa.gov","environment":"production","featureFlags":{"notify_import_result":false,"captcha_on_nominations":true,"embetter_analytics_page":false,"visualization_canvas_embed_button":"edit-only","enable_colocate_ui":false,"enable_catalog_federator_connector":true,"display_dataset_landing_page_notice":false,"ignore_hiding_columns_unhidden_on_derived_views":true,"feature_map_default_extent":"\'{\\"southwe
# ...

# %%
#verify that JSON object is one big dictionary
type(str_data)
# Out:
# str

# %%
nasa = json.loads(str_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-26-97ec8dab1f32> in <module>()
# ----> 1 nasa = json.loads(str_data)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
from bs4 import BeautifulSoup

# %%
nasa1 = BeautifulSoup(resp, "lxml")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-0ede61d6749c> in <module>()
# ----> 1 nasa1 = BeautifulSoup(resp, "lxml")
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     244         if hasattr(markup, 'read'):        # It's a file-type object.
#     245             markup = markup.read()
# --> 246         elif len(markup) <= 256 and (
#     247                 (isinstance(markup, bytes) and not b'<' in markup)
#     248                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
nasa1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <!--
#   Powered by Socrata
#   http://www.socrata.com
#   -->
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="Ncvge3O+ds9JVRoeQJ8/i5r6iuPpgwIlUD9eGCJEX7PiTEwQ/6mUFRAp7B3NkzyP0QupTRmyrWzwa7Oo+NAykQ==" name="csrf-token"/>
# <script src="/javascripts/build/shared/polyfills.js?15f121d5947a8278333c94906e50e1f198ea80a6.2945.1498250080"></script>
# <script>
# //<![CDATA[
# ...

# %%
print(resp)
# Out:
# <Response [200]>

# %%
print (nasa1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <!--
#   Powered by Socrata
#   http://www.socrata.com
#   -->
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="Ncvge3O+ds9JVRoeQJ8/i5r6iuPpgwIlUD9eGCJEX7PiTEwQ/6mUFRAp7B3NkzyP0QupTRmyrWzwa7Oo+NAykQ==" name="csrf-token"/>
#   <script src="/javascripts/build/shared/polyfills.js?15f121d5947a8278333c94906e50e1f198ea80a6.2945.1498250080">
#   </script>
#   <script>
#    //<![CDATA[
# ...

# %%
#Get all the tables in the file
all_tables=nasa1.find_all('table')
all_tables
# Out:
# []

# %%
nasa1.title
# Out:
# <title>Meteorite Landings | NASA Open Data Portal</title>

# %%
nasa1.find_all("a")
# Out:
# [<a class="skip-link" href="#content" title="skip to content">
#          Skip to Main Content
#        </a>,
#  <a class="logo" href="/"><img alt='NASA "meatball" logo' onerror='this.style.display="none"' src="/api/assets/101AE2CD-4D6B-45E2-B2D6-30B36F639398"/><span class="site-name">NASA's Open Data Portal</span></a>,
#  <a class="sign-in-toggle site-chrome-btn" href="/login">Sign In</a>,
#  <a class="site-chrome-nav-link site-chrome-social-link noselect" href="https://github.com/nasa/" target="_blank">
#  <span class="monosocial"></span></a>,
#  <a class="site-chrome-nav-link site-chrome-social-link noselect" href="https://www.facebook.com/NASA" target="_blank">
#  <span class="monosocial"></span></a>,
#  <a class="site-chrome-nav-link site-chrome-social-link noselect" href="https://twitter.com/NASA" target="_blank">
#  <span class="monosocial"></span></a>,
# ...

# %%
all_tables=nasa1.find_all('table')
all_tables
# Out:
# []

# %%
tables = nasa1.findAll("table")

for table in tables:
    if table.findParent("table") is None:
        print str(table)
# Out:
#   File "<ipython-input-50-cdf12b17be8d>", line 5
#     print str(table)
#             ^
# SyntaxError: invalid syntax
