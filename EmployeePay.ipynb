# %%
import sys

# %%
name= ('Ray')
payrate= 16.50
hours = 80
if hours <=40:
    pay = payrate * hours
else:
    overtime = hours - 40
    pay= 40 * payrate + overtime * 1.5 * payrate
    print("pay is ",pay)
# Out:
# pay is  1650.0
